# %%
import time
from Arm_Lib import Arm_Device
Arm = Arm_Device()
time.sleep(.1)
def arm_move(p, s_time = 500):
    for i in range(5):
        id = i + 1
        if id == 5:
            Arm.Arm_serial_servo_write(id, p[i], int(s_time*1.2))
        elif id == 1 :
            Arm.Arm_serial_servo_write(id, p[i], int(3*s_time/4))
        else:
            Arm.Arm_serial_servo_write(id, p[i], int(s_time))
        time.sleep(.01)
p_mould = [90, 130, 0, 0, 90]
p_top = [90, 80, 50, 50, 270]
p_layer_4 = [90, 76, 40, 17, 270]
p_layer_3 = [90, 65, 44, 17, 270]
p_layer_2 = [90, 65, 25, 36, 270]
p_layer_1 = [90, 48, 35, 30, 270]
p_y = [65, 22, 64, 56, 270]
p_r = [118, 19, 66, 56, 270]
p_g = [136, 66, 20, 28, 270]
p_b = [44, 66, 20, 28, 270]
int1=input("What color on the bottom (r,g,b,y)")
int2=input("Next (r,g,b,y)")
int3=input("Third (r,g,b,y)")
int4=input("Last (r,g,b,y)")
if int1=="r":
    arm_move(p_mould)
    arm_move(p_top)
    arm_move(p_r)
    time.sleep(.1)
    Arm.Arm_serial_servo_write(6, 140, 400)
    time.sleep(.5)
    arm_move(p_top)
    arm_move(p_layer_1)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 60, 400)
    arm_move(p_mould)
    
     
elif int1=="g":
    arm_move(p_mould)
    arm_move(p_top)
    arm_move(p_g)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 140, 400)
    arm_move(p_top)
    arm_move(p_layer_1)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 60, 400)
    arm_move(p_mould)
elif int1=="b":
    arm_move(p_mould)
    arm_move(p_top)
    arm_move(p_b)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 140, 400)
    arm_move(p_top)
    arm_move(p_layer_1)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 60, 400)
    arm_move(p_mould)
elif int1=="y":
    arm_move(p_mould)
    arm_move(p_top)
    arm_move(p_y)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 140, 400)
    arm_move(p_top)
    arm_move(p_layer_1)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 60, 400)
    arm_move(p_mould)
if int2=="r":
    
    arm_move(p_mould)
    arm_move(p_top)
    arm_move(p_r)
    Arm.Arm_serial_servo_write(6, 140, 400)
    time.sleep(.5)
    arm_move(p_top)
    arm_move(p_layer_2)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 60, 400)
    arm_move(p_mould)
    
     
elif int2=="g":
    arm_move(p_mould)
    arm_move(p_top)
    arm_move(p_g)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 140, 400)
    arm_move(p_top)
    arm_move(p_layer_2)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 60, 400)
    arm_move(p_mould)
elif int2=="b":
    arm_move(p_mould)
    arm_move(p_top)
    arm_move(p_b)
    Arm.Arm_serial_servo_write(6, 140, 400)
    time.sleep(.5)
    arm_move(p_top)
    arm_move(p_layer_2)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 60, 400)
    arm_move(p_mould)
elif int2=="y":
    arm_move(p_mould)
    arm_move(p_top)
    arm_move(p_y)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 140, 400)
    arm_move(p_top)
    arm_move(p_layer_2)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 60, 400)
    arm_move(p_mould)
if int3=="r":
    
    
    arm_move(p_mould)
    arm_move(p_top)
    arm_move(p_r)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 140, 400)
    arm_move(p_top)
    arm_move(p_layer_3)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 60, 400)
    arm_move(p_mould)
    
     
elif int3=="g":
    arm_move(p_mould)
    arm_move(p_top)
    arm_move(p_g)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 140, 400)
    arm_move(p_top)
    arm_move(p_layer_3)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 60, 400)
    arm_move(p_mould)
elif int3=="b":
    arm_move(p_mould)
    arm_move(p_top)
    arm_move(p_b)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 140, 400)
    arm_move(p_top)
    arm_move(p_layer_3)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 60, 400)
    arm_move(p_mould)
elif int3=="y":
    arm_move(p_mould)
    arm_move(p_top)
    arm_move(p_y)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 140, 400)
    arm_move(p_top)
    arm_move(p_layer_3)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 60, 400)
    arm_move(p_mould)
if int4=="r":
        
    arm_move(p_mould)
    arm_move(p_top)
    arm_move(p_r)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 140, 400)
    arm_move(p_top)
    arm_move(p_layer_4)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 60, 400)
    arm_move(p_mould)
    
     
elif int4=="g":
    arm_move(p_mould)
    arm_move(p_top)
    arm_move(p_g)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 140, 400)
    arm_move(p_top)
    arm_move(p_layer_4)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 60, 400)
    arm_move(p_mould)
elif int4=="b":
    arm_move(p_mould)
    arm_move(p_top)
    arm_move(p_b)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 140, 400)
    arm_move(p_top)
    arm_move(p_layer_4)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 60, 400)
    arm_move(p_mould)
elif int4=="y":
    arm_move(p_mould)
    arm_move(p_top)
    arm_move(p_y)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 140, 400)
    arm_move(p_top)
    arm_move(p_layer_4)
    time.sleep(.5)
    Arm.Arm_serial_servo_write(6, 60, 400)
    arm_move(p_mould)
